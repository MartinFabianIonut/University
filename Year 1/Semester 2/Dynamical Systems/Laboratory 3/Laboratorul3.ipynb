# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst, [x,y,z],[0,C1,C2,C3])
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==(-6)*x-4*y+e^(-t)
syst=[deq1,deq2]
C1,C2=var('C1,C2')
show(desolve_system(syst, [x,y],[0,C1,C2]))
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+3*y+cos(t)
deq2=diff(y,t)==x-y+2*t
syst=[deq1,deq2]
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-2*y-2*z+e^(-t)
deq2=diff(y,t)==-2*x+y+2*z
deq3=diff(z,t)==2*x-y-3*z+e^(-t)
syst=[deq1,deq2,deq3]
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst, [x,y,z],[0,C1,C2,C3])
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]
sol=desolve_system(syst, vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t),t,-1,3,color='red')
g2=plot(sol_y(t),t,-1,3,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==-2*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst, vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*y+e^(-t)
deq2=diff(y,t)==-2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst, vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==-x+3*y+3*z+27*t^2
deq2=diff(y,t)==2*x-2*y-5*z+3*t
deq3=diff(z,t)==-2*x+3*y+6*z+3
syst=[deq1,deq2,deq3]
vars=[x,y,z]
in_cond=[0,50,-30,26]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
sol_z(t)=sol[2].rhs()
g1=plot(sol_x(t),t,-1,2,color='red')
g2=plot(sol_y(t),t,-1,2,color='blue')
g3=plot(sol_z(t),t,-1,2,color='green')
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+y
deq2=diff(y,t)==-2*x+4*y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,3,0]
sol=desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
show(limit(sol[0],t=infinity))
show(limit(sol[1],t=infinity))
show(sol_x)
show(sol_y)
in_cond2=[0,0,3]
sol2=desolve_system(syst, vars, in_cond2)
show(sol2)
sol_x2(t)=sol2[0].rhs()
sol_y2(t)=sol2[1].rhs()
show(limit(sol2[0],t=infinity))
show(limit(sol2[1],t=infinity))
show(sol_x2)
show(sol_y2)
in_cond3=[0,-3,0]
sol3=desolve_system(syst, vars, in_cond3)
show(sol3)
sol_x3(t)=sol3[0].rhs()
sol_y3(t)=sol3[1].rhs()
show(limit(sol3[0],t=infinity))
show(limit(sol3[1],t=infinity))
show(sol_x3)
show(sol_y3)
in_cond4=[0,0,-3]
sol4=desolve_system(syst, vars, in_cond4)
show(sol4)
sol_x4(t)=sol4[0].rhs()
sol_y4(t)=sol4[1].rhs()
show(limit(sol4[0],t=infinity))
show(limit(sol4[1],t=infinity))
show(sol_x4)
show(sol_y4)
f1(u,v)=u+v
f2(u,v)=-2*u+4*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-8,8], [v,-8,8],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -10, 10),color='blue')
g3=parametric_plot((sol_x2(t), sol_y2(t)), (t, -10, 10),color='green')
g4=parametric_plot((sol_x3(t), sol_y3(t)), (t, -10, 10),color='purple')
g5=parametric_plot((sol_x4(t), sol_y4(t)), (t, -10, 10),color='orange')
g=g1+g2+g3+g4+g5
g.show(xmin=-8,xmax=8,ymin=-8,ymax=8)
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]
# limit(x(t), t, +Infinity) == -Infinity
# limit(y(t), t, +Infinity) == -Infinity
# t |--> -3*e^(3*t) + 6*e^(2*t)
# t |--> -6*e^(3*t) + 6*e^(2*t)
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]
# limit(x(t), t, +Infinity) == +Infinity
# limit(y(t), t, +Infinity) == +Infinity
# t |--> 3*e^(3*t) - 3*e^(2*t)
# t |--> 6*e^(3*t) - 3*e^(2*t)
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]
# limit(x(t), t, +Infinity) == +Infinity
# limit(y(t), t, +Infinity) == +Infinity
# t |--> 3*e^(3*t) - 6*e^(2*t)
# t |--> 6*e^(3*t) - 6*e^(2*t)
# [x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t)]
# limit(x(t), t, +Infinity) == -Infinity
# limit(y(t), t, +Infinity) == -Infinity
# t |--> -3*e^(3*t) + 3*e^(2*t)
# t |--> -6*e^(3*t) + 3*e^(2*t)
# Graphics object consisting of 5 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x-2*y
syst=[deq1,deq2]
vars=[x,y]
C1,C2=var('C1,C2')
sol=desolve_system(syst, vars,[0,1,2])
show(sol)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
show(limit(sol[0],t=infinity))
show(limit(sol[1],t=infinity))
f1(u,v)=v
f2(u,v)=-u-2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# [x(t) == 3*t*e^(-t) + e^(-t), y(t) == -3*t*e^(-t) + 2*e^(-t)]
# limit(x(t), t, +Infinity) == 0
# limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x+y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,3,0]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
f1(u,v)=2*u+v
f2(u,v)=u+2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# limit(x(t), t, +Infinity) == +Infinity
# limit(y(t), t, +Infinity) == +Infinity
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==-x-y
deq2=diff(y,t)==x-y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,3,1]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
f1(u,v)=-u-v
f2(u,v)=u-v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# limit(x(t), t, +Infinity) == 0
# limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,2,2]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
f1(u,v)=v
f2(u,v)=-u
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# limit(x(t), t, +Infinity) == ind
# limit(y(t), t, +Infinity) == ind
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==-2*x
deq2=diff(y,t)==-4*x-2*y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,3,0]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
f1(u,v)=-2*u
f2(u,v)=-4*u-2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# limit(x(t), t, +Infinity) == 0
# limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-4*y
deq2=diff(y,t)==5*x-3*y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,3,1]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
f1(u,v)=u-4*v
f2(u,v)=5*u-3*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# limit(x(t), t, +Infinity) == 0
# limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==3*x-y
deq2=diff(y,t)==y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,3,3]
sol=desolve_system(syst, vars, in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
f1(u,v)=3*u-v
f2(u,v)=v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
g1=plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-4,4], [v,-4,4],color='red' ,aspect_ratio = 1, )
g2=parametric_plot((sol_x(t), sol_y(t)), (t, -4, 4),color='blue')
g=g1+g2
g.show(xmin=-4,xmax=4,ymin=-4,ymax=4)
# Out:
# Graphics object consisting of 2 graphics primitives
