# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*(1+y^2)
sol=desolve(eqd,y)
show(sol)
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
g1=implicit_plot(f(x,yy,0),(x,-30,20),(yy,-30,20),color='red')
g2=implicit_plot(f(x,yy,-13),(x,-30,20),(yy,-30,20))
show(g1+g2)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C
# Graphics object consisting of 2 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=(x^2-1)*diff(y,x)+2*x*y^2==0
sol=desolve(eqd,y)
show(sol)
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
g1=implicit_plot(f(x,yy,1),(x,-2,8),(yy,-5,8),color='red')
g2=implicit_plot(f(x,yy,2),(x,-2,8),(yy,-5,8))
g3=implicit_plot(f(x,yy,-2),(x,-2,8),(yy,-5,8),color='green')
show(g1+g2+g3)
# Out:
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)
# Graphics object consisting of 3 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=(x^2)*diff(y,x)==x*y+y^2
sol=desolve(eqd,y)
show(sol)
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
g1=implicit_plot(f(x,yy,2),(x,-40,40),(yy,-40,40),color='red')
g2=implicit_plot(f(x,yy,-2),(x,-40,40),(yy,-40,40))
g3=implicit_plot(f(x,yy,130),(x,-40,40),(yy,-40,40),color='green')
show(g1+g2+g3)
# Out:
# _C*x == e^(-x/y(x))
# Graphics object consisting of 3 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==-(x+y)/y
sol=desolve(eqd,y)
show(sol)
yy=var('yy')
sol.substitute(y(x)==yy)
_C=var('_C')
f(x,yy,_C)=sol.substitute(y(x)==yy)
g1=implicit_plot(f(x,yy,1),(x,-2,2),(yy,-4,4),color='red')
g2=implicit_plot(f(x,yy,3),(x,-2,2),(yy,-4,4))
g3=implicit_plot(f(x,yy,-2),(x,-2,2),(yy,-4,4),color='green')
show(g1+g2+g3)
# Out:
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*y(x) + y(x)^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*y(x))/x)))
# Graphics object consisting of 3 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+diff(y,x)==sin(x)+cos(x)
sol=desolve(eqd,y)
show(sol)
_K1,_K2=var('_K1,_K2')
sol1=sol.substitute(_K1==1,_K2==3)
sol2=sol.substitute(_K1==3,_K2==9)
sol3=sol.substitute(_K1==-1,_K2==-3)
plot([sol1,sol2,sol3],x,-2,2,color=['red','blue','green'])
# Out:
# _K2*e^(-x) + _K1 - cos(x)
# Graphics object consisting of 3 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)==e^(2*x)
sol=desolve(eqd,y)
show(sol)
_K1,_K2=var('_K1,_K2')
sol1=sol.substitute(_K1==-3,_K2==2)
sol2=sol.substitute(_K1==-6,_K2==4)
sol3=sol.substitute(_K1==2,_K2==2)
plot([sol1,sol2,sol3],x,-2,2,color=['red','blue','green'])
# Out:
# _K1*e^x + _K2 + 1/2*e^(2*x)
# Graphics object consisting of 3 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)==1/(1+e^x)
sol=desolve(eqd,y)
show(sol)
_K1,_K2=var('_K1,_K2')
sol1=sol.substitute(_K1==-12,_K2==5)
sol1=sol.substitute(_K1==12,_K2==-5)
sol1=sol.substitute(_K1==2,_K2==5)
plot([sol1,sol2,sol3],x,-2,2,color=['red','blue','green'])
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)
# Graphics object consisting of 3 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
sol = desolve(eqd,y,ics=[0,1])
show(sol)
yy=var('yy')
sol.substitute(y(x)==yy)
f(x,yy)=sol.substitute(y(x)==yy)
implicit_plot(f(x,yy),(x,-4,4),(yy,-8,8))
# Out:
# arctan(y(x)) == 1/4*pi + x
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(1/(1-x^2))*y+1+x
sol = desolve(eqd,y,ics=[2,0])
show(sol)
plot(sol,x,-1,10)
# Out:
# 1/2*(sqrt(x^2 - 1)*sqrt(x + 1)*x - sqrt(x + 1)*(2*sqrt(3) - log(2*sqrt(3) + 4)) - sqrt(x + 1)*log(2*x + 2*sqrt(x^2 - 1)))/sqrt(x - 1)
# verbose 0 (3839: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 37 points.
# verbose 0 (3839: plot.py, generate_plot_points) Last error message: 'math domain error'
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)-2*y==-x^2
sol = desolve(eqd,y,ics=[0,1/4])
show(sol)
plot(sol,x,-3,3)
# Out:
# 1/2*x^2 + 1/2*x + 1/4
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-5*diff(y,x)+4*y==0
sol = desolve(eqd,y,ics=[0,5,8])
show(sol)
plot(sol,x,-4,4)
# Out:
# e^(4*x) + 4*e^x
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-4*diff(y,x)+5*y==2*(x^2)*(e^x)
sol = desolve(eqd,y,ics=[0,2,3])
show(sol)
plot(sol,x,-4,4)
# Out:
# (cos(x) - 2*sin(x))*e^(2*x) + (x^2 + 2*x + 1)*e^x
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+4*y==4*(sin(2*x)+cos(2*x))
sol = desolve(eqd,y,ics=[pi,2*pi,2*pi])
show(sol)
plot(sol,x,-40,40)
# Out:
# 1/2*(6*pi - 1)*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) + x*sin(2*x) + 1/2*sin(2*x)
# Graphics object consisting of 1 graphics primitive

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol(x,k)=desolve(eqd,[y,x])
show(sol)
_C=var('_C')
sol1=sol(x,1).substitute(_C==1)
sol2=sol(x,1).substitute(_C==20)
sol3=sol(x,1).substitute(_C==-33)
plot([sol1,sol2,sol3],x,1,2,color=['red','blue','green'])
# Out:
# (x, k) |--> (x^4*x^k/(k + 4) + _C)/x^k
# Graphics object consisting of 3 graphics primitives

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol2(x,k) = desolve(eqd,[y,x],ics=[1,0])
show(sol2)
plot(sol2(x,1),x,1,2)
# Out:
# (x, k) |--> (x^4*x^k - 1)/((k + 4)*x^k)
# Graphics object consisting of 1 graphics primitive

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)+(k/x)*y==x^3
sol2(x,k) = desolve(eqd,[y,x],ics=[1,0])
show(sol2)
sols=[plot(sol2(x,k/20),x,1,3,ymin=0,ymax=30) for k in [-20..20]]
animate(sols)
# Out:
# (x, k) |--> (x^4*x^k - 1)/((k + 4)*x^k)
# Animation with 41 frames

# %%
x=var('x')
a=var('a')
b=var('b')
y=function('y')(x)
eqd(x,a,b)=diff(y,x)==y+a*x+b
f(x,a,b)=desolve(eqd(x,a,b),[y,x],ics=[0,1])
show(f)
syst=[f(1,a,b)==-5+4*e,f(2,a,b)==-7+4*e^2]
show(solve(syst,a,b))
plot(f(x,2,1),x,-2,5)
# Out:
# (x, a, b) |--> -a*x + (a + b + 1)*e^x - a - b
# [[a == 2, b == 1]]
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
a=var('a')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)-2*y==0
sol = desolve(eqd,y,ics=[0,a,2])
show(sol)
show(solve(limit(y,x=infinity)==0,a))
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)
# []

# %%
limit(y,x=infinity)==0
# Out:
# limit(y(x), x, +Infinity) == 0

# %%
ysol(x,a)=sol
ysol(x,a)
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)

# %%
ysol(x,-2)
# Out:
# -2*e^(-x)

# %%
limit(ysol(x,-2),x=infinity)
# Out:
# 0

# %%
x=var('x')
a=var('a')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)-2*y==0
sol = desolve(eqd,y,ics=[0,a,2])
show(sol)
ysol(x,a)=sol
limit(ysol(x,-2),x=infinity)
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)
# 0
